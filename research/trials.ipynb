# %%
#ConfigBox
d = {
        "key": "val",
        "key1": "val1"
 }

# %%
d["key"]
# Out:
# 'val'

# %%
from box import ConfigBox
d = ConfigBox({
        "key": "val",
        "key1": "val1"
 })

# %%
d.key
# Out:
# 'val'

# %%
#ensure annotations

def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(2, "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y
